# %%
import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt


import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util

import warnings
warnings.filterwarnings("ignore")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %%
spotify_df = pd.read_csv('data.csv')

# %%
data_w_genre = pd.read_csv('data_w_genres.csv')
data_w_genre['genres_upd'] = data_w_genre['genres'].apply(lambda x: [re.sub(' ','_',i) for i in re.findall(r"'([^']*)'", x)])

# %%
spotify_df['artists_upd_v1'] = spotify_df['artists'].apply(lambda x: re.findall(r"'([^']*)'", x))

# %%
spotify_df['artists'].values[0]
# Out:
# "['Carl Woitschach']"

# %%
spotify_df['artists_upd_v1'].values[0][0]
# Out:
# 'Carl Woitschach'

# %%
spotify_df['artists_upd_v2'] = spotify_df['artists'].apply(lambda x: re.findall('\"(.*?)\"',x))
spotify_df['artists_upd'] = np.where(spotify_df['artists_upd_v1'].apply(lambda x: not x), spotify_df['artists_upd_v2'], spotify_df['artists_upd_v1'] )

# %%
spotify_df['artists_song'] = spotify_df.apply(lambda row: row['artists_upd'][0]+row['name'],axis = 1)

# %%
spotify_df.sort_values(['artists_song','release_date'], ascending = False, inplace = True)

# %%
spotify_df.drop_duplicates('artists_song',inplace = True)

# %%
artists_exploded = spotify_df[['artists_upd','id']].explode('artists_upd')

# %%
artists_exploded_enriched = artists_exploded.merge(data_w_genre, how = 'left', left_on = 'artists_upd',right_on = 'artists')
artists_exploded_enriched_nonnull = artists_exploded_enriched[~artists_exploded_enriched.genres_upd.isnull()]

# %%
artists_genres_consolidated = artists_exploded_enriched_nonnull.groupby('id')['genres_upd'].apply(list).reset_index()

# %%
artists_genres_consolidated['consolidates_genre_lists'] = artists_genres_consolidated['genres_upd'].apply(lambda x: list(set(list(itertools.chain.from_iterable(x)))))

# %%
spotify_df = spotify_df.merge(artists_genres_consolidated[['id','consolidates_genre_lists']], on = 'id',how = 'left')

# %%
spotify_df['year'] = spotify_df['release_date'].apply(lambda x: x.split('-')[0])

# %%
float_cols = spotify_df.dtypes[spotify_df.dtypes == 'float64'].index.values

# %%
ohe_cols = 'popularity'

# %%
spotify_df['popularity_red'] = spotify_df['popularity'].apply(lambda x: int(x/5))

# %%
spotify_df['consolidates_genre_lists'] = spotify_df['consolidates_genre_lists'].apply(lambda d: d if isinstance(d, list) else [])

# %%
def ohe_prep(df, column, new_name): 
    
    tf_df = pd.get_dummies(df[column])
    feature_names = tf_df.columns
    tf_df.columns = [new_name + "|" + str(i) for i in feature_names]
    tf_df.reset_index(drop = True, inplace = True)    
    return tf_df

# %%
def create_feature_set(df, float_cols):

    tfidf = TfidfVectorizer()
    tfidf_matrix =  tfidf.fit_transform(df['consolidates_genre_lists'].apply(lambda x: " ".join(x)))
    genre_df = pd.DataFrame(tfidf_matrix.toarray())
    genre_df.columns = ['genre' + "|" + i for i in tfidf.get_feature_names()]
    genre_df.reset_index(drop = True, inplace=True)

    year_ohe = ohe_prep(df, 'year','year') * 0.5
    popularity_ohe = ohe_prep(df, 'popularity_red','pop') * 0.15

    floats = df[float_cols].reset_index(drop = True)
    scaler = MinMaxScaler()
    floats_scaled = pd.DataFrame(scaler.fit_transform(floats), columns = floats.columns) * 0.2

    final = pd.concat([genre_df, floats_scaled, popularity_ohe, year_ohe], axis = 1)
     
    final['id']=df['id'].values
    
    return final

# %%
complete_feature_set = create_feature_set(spotify_df, float_cols=float_cols)

# %%
client_id = ''
client_secret= ''
redirect="http://example.com/"

# %%
scope = 'user-library-read'

if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Usage: %s username" % (sys.argv[0],))
    sys.exit()

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret) 
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
token = util.prompt_for_user_token(scope, client_id= client_id, client_secret=client_secret,redirect_uri=redirect)

# %%
sp = spotipy.Spotify(auth=token)

# %%
id_name = {}
#list_photo = {}
for i in sp.current_user_playlists()['items']:

    id_name[i['name']] = i['uri'].split(':')[2]
    #list_photo[i['uri'].split(':')[2]] = i['images'][0]['url']

# %%
id_name
# Out:
# {'Sample Playlist': '46evaGrctDxKY3fMtKgSzc'}

# %%
def create_necessary_outputs(playlist_name,id_dic, df):

    playlist = pd.DataFrame()
    playlist_name = playlist_name

    for ix, i in enumerate(sp.playlist(id_dic[playlist_name])['tracks']['items']):
        playlist.loc[ix, 'artist'] = i['track']['artists'][0]['name']
        playlist.loc[ix, 'name'] = i['track']['name']
        playlist.loc[ix, 'id'] = i['track']['id'] # ['uri'].split(':')[2]
        playlist.loc[ix, 'url'] = i['track']['album']['images'][1]['url']
        playlist.loc[ix, 'date_added'] = i['added_at']

    playlist['date_added'] = pd.to_datetime(playlist['date_added'])  
    
    playlist = playlist[playlist['id'].isin(df['id'].values)].sort_values('date_added',ascending = False)
    
    return playlist

# %%
playlist_EDM = create_necessary_outputs('Sample Playlist', id_name,spotify_df)

# %%
from skimage import io
import matplotlib.pyplot as plt

def visualize_songs(df):

    temp = df['url'].values
    plt.figure(figsize=(15,int(0.625 * len(temp))))
    columns = 5
    
    for i, url in enumerate(temp):
        plt.subplot(len(temp) / columns + 1, columns, i + 1)

        image = io.imread(url)
        plt.imshow(image)
        plt.xticks(color = 'w', fontsize = 0.1)
        plt.yticks(color = 'w', fontsize = 0.1)
        plt.xlabel(df['name'].values[i], fontsize = 12)
        plt.tight_layout(h_pad=0.4, w_pad=0)
        plt.subplots_adjust(wspace=None, hspace=None)

    plt.show()

# %%
playlist_EDM
# Out:
#             artist                                               name  \
# 9   Michael Hunter  Soviet Connection — The Theme from Grand Theft...
# 12    Young Maylay                             San Andreas Theme Song
# 14   John Williams                                 Anakin vs. Obi-Wan
# 27     Hans Zimmer                                     Discombobulate
# 33     Lorne Balfe                    Assassin's Creed III Main Theme
# 34     Brian Tyler          Assassin's Creed IV Black Flag Main Theme
# 37        I'm Blue                                   Blue (Da Ba Dee)
# 38   John Williams                                  Duel of the Fates
# 43    Danny Elfman                            Spider-Man 2 Main Title
# 44   John Williams  Across the Stars (Love Theme from "Star Wars: ...
# 46   John Williams           The Imperial March (Darth Vader's Theme)
#
#                         id                                                url  \
# 9   3LoTSUEm7h7uryGBWxtaFe  https://i.scdn.co/image/ab67616d00001e0243692d...
# 12  5f7F8ovtEmFzOdyN5fTOKl  https://i.scdn.co/image/ab67616d00001e0293d872...
# 14  3fzL0RuACZtv5cQ6R78Sjq  https://i.scdn.co/image/ab67616d00001e02dfd165...
# 27  0cm6cAtRu0C0sEZzDjZFsx  https://i.scdn.co/image/ab67616d00001e02796560...
# 33  3Pyb7rYWBsRL24vmdlzlxk  https://i.scdn.co/image/ab67616d00001e0209b5a3...
# 34  6enLk2V2s0M6D6PGLjHxYv  https://i.scdn.co/image/ab67616d00001e02c6d155...
# 37  0nHQAxZgzAcKGRxAsOISTc  https://i.scdn.co/image/ab67616d00001e021c42b9...
# 38  1ghlpxVfPbFH2jenrv9vVw  https://i.scdn.co/image/ab67616d00001e028b3448...
# 43  2v3Ezj7MnwBe3s1VRaUcDt  https://i.scdn.co/image/ab67616d00001e02e7ed40...
# 44  3rUMH7i22tlkymhDPOmXUv  https://i.scdn.co/image/ab67616d00001e023eeec5...
# 46  2bw4WgXyXP90hIex7ur58y  https://i.scdn.co/image/ab67616d00001e021e869a...
#
#                   date_added
# 9  2021-12-17 14:05:02+00:00
# 12 2021-12-17 14:05:02+00:00
# 14 2021-12-17 14:05:02+00:00
# 27 2021-12-17 14:05:02+00:00
# 33 2021-12-17 14:05:02+00:00
# 34 2021-12-17 14:05:02+00:00
# 37 2021-12-17 14:05:02+00:00
# 38 2021-12-17 14:05:02+00:00
# 43 2021-12-17 14:05:02+00:00
# 44 2021-12-17 14:05:02+00:00
# 46 2021-12-17 14:05:02+00:00

# %%
visualize_songs(playlist_EDM)

# %%
def generate_playlist_feature(complete_feature_set, playlist_df, weight_factor):

    complete_feature_set_playlist = complete_feature_set[complete_feature_set['id'].isin(playlist_df['id'].values)]#.drop('id', axis = 1).mean(axis =0)
    complete_feature_set_playlist = complete_feature_set_playlist.merge(playlist_df[['id','date_added']], on = 'id', how = 'inner')
    complete_feature_set_nonplaylist = complete_feature_set[~complete_feature_set['id'].isin(playlist_df['id'].values)]#.drop('id', axis = 1)
    
    playlist_feature_set = complete_feature_set_playlist.sort_values('date_added',ascending=False)

    most_recent_date = playlist_feature_set.iloc[0,-1]
    
    for ix, row in playlist_feature_set.iterrows():
        playlist_feature_set.loc[ix,'months_from_recent'] = int((most_recent_date.to_pydatetime() - row.iloc[-1].to_pydatetime()).days / 30)
        
    playlist_feature_set['weight'] = playlist_feature_set['months_from_recent'].apply(lambda x: weight_factor ** (-x))
    
    playlist_feature_set_weighted = playlist_feature_set.copy()
    #print(playlist_feature_set_weighted.iloc[:,:-4].columns)
    playlist_feature_set_weighted.update(playlist_feature_set_weighted.iloc[:,:-4].mul(playlist_feature_set_weighted.weight,0))
    playlist_feature_set_weighted_final = playlist_feature_set_weighted.iloc[:, :-4]
    #playlist_feature_set_weighted_final['id'] = playlist_feature_set['id']
    
    return playlist_feature_set_weighted_final.sum(axis = 0), complete_feature_set_nonplaylist

# %%
complete_feature_set_playlist_vector_EDM, complete_feature_set_nonplaylist_EDM = generate_playlist_feature(complete_feature_set, playlist_EDM, 1.09)

# %%
def generate_playlist_recos(df, features, nonplaylist_features):

    
    non_playlist_df = df[df['id'].isin(nonplaylist_features['id'].values)]
    non_playlist_df['sim'] = cosine_similarity(nonplaylist_features.drop('id', axis = 1).values, features.values.reshape(1, -1))[:,0]
    non_playlist_df_top_40 = non_playlist_df.sort_values('sim',ascending = False).head(40)
    non_playlist_df_top_40['url'] = non_playlist_df_top_40['id'].apply(lambda x: sp.track(x)['album']['images'][1]['url'])
    
    return non_playlist_df_top_40

# %%
edm_top40 = generate_playlist_recos(spotify_df, complete_feature_set_playlist_vector_EDM, complete_feature_set_nonplaylist_EDM)

# %%
edm_top40
# Out:
#        acousticness                                         artists  \
# 85565         0.783  ['John Williams', 'London Symphony Orchestra']
# 85574         0.772  ['John Williams', 'London Symphony Orchestra']
# 85573         0.823  ['John Williams', 'London Symphony Orchestra']
# 85531         0.410  ['John Williams', 'London Symphony Orchestra']
# 85445         0.377  ['John Williams', 'London Symphony Orchestra']
# 85580         0.719  ['John Williams', 'London Symphony Orchestra']
# 85413         0.566  ['John Williams', 'London Symphony Orchestra']
# 85547         0.746  ['John Williams', 'London Symphony Orchestra']
# 85528         0.857  ['John Williams', 'London Symphony Orchestra']
# 85430         0.925  ['John Williams', 'London Symphony Orchestra']
# 85446         0.524  ['John Williams', 'London Symphony Orchestra']
# 85395         0.490  ['John Williams', 'London Symphony Orchestra']
# 85431         0.536  ['John Williams', 'London Symphony Orchestra']
# 85447         0.390  ['John Williams', 'London Symphony Orchestra']
# 85433         0.391  ['John Williams', 'London Symphony Orchestra']
# 85539         0.559  ['John Williams', 'London Symphony Orchestra']
# 85463         0.534  ['John Williams', 'London Symphony Orchestra']
# 85423         0.798  ['John Williams', 'London Symphony Orchestra']
# 85568         0.450  ['John Williams', 'London Symphony Orchestra']
# 85516         0.623  ['John Williams', 'London Symphony Orchestra']
# 85556         0.776  ['John Williams', 'London Symphony Orchestra']
# 85497         0.584  ['John Williams', 'London Symphony Orchestra']
# 85424         0.781  ['John Williams', 'London Symphony Orchestra']
# 85435         0.787  ['John Williams', 'London Symphony Orchestra']
# 85416         0.449  ['John Williams', 'London Symphony Orchestra']
# 85558         0.773  ['John Williams', 'London Symphony Orchestra']
# 85392         0.858  ['John Williams', 'London Symphony Orchestra']
# 85407         0.605  ['John Williams', 'London Symphony Orchestra']
# 85572         0.443  ['John Williams', 'London Symphony Orchestra']
# 85500         0.856  ['John Williams', 'London Symphony Orchestra']
# 85504         0.930  ['John Williams', 'London Symphony Orchestra']
# 85525  [John Williams, London Symphony Orchestra]             []
# 85426  [John Williams, London Symphony Orchestra]             []
#
#                                       artists_upd  \
# 85565  [John Williams, London Symphony Orchestra]
# 85574  [John Williams, London Symphony Orchestra]
# 85573  [John Williams, London Symphony Orchestra]
# 85531  [John Williams, London Symphony Orchestra]
# 85445  [John Williams, London Symphony Orchestra]
# 85580  [John Williams, London Symphony Orchestra]
# 85413  [John Williams, London Symphony Orchestra]
# 85547  [John Williams, London Symphony Orchestra]
# 85528  [John Williams, London Symphony Orchestra]
# 85430  [John Williams, London Symphony Orchestra]
# 85446  [John Williams, London Symphony Orchestra]
# 85395  [John Williams, London Symphony Orchestra]
# 85431  [John Williams, London Symphony Orchestra]
# 85447  [John Williams, London Symphony Orchestra]
# 85433  [John Williams, London Symphony Orchestra]
# 85539  [John Williams, London Symphony Orchestra]
# 85463  [John Williams, London Symphony Orchestra]
# 85423  [John Williams, London Symphony Orchestra]
# 85568  [John Williams, London Symphony Orchestra]
# 85516  [John Williams, London Symphony Orchestra]
# 85556  [John Williams, London Symphony Orchestra]
# 85497  [John Williams, London Symphony Orchestra]
# 85424  [John Williams, London Symphony Orchestra]
# 85435  [John Williams, London Symphony Orchestra]
# 85416  [John Williams, London Symphony Orchestra]
# 85558  [John Williams, London Symphony Orchestra]
# 85392  [John Williams, London Symphony Orchestra]
# 85407  [John Williams, London Symphony Orchestra]
# 85572  [John Williams, London Symphony Orchestra]
# 85500  [John Williams, London Symphony Orchestra]
# 85504  [John Williams, London Symphony Orchestra]
# 85467  [John Williams, London Symphony Orchestra]
# 85375  [John Williams, London Symphony Orchestra]
# 85391  [John Williams, London Symphony Orchestra]
# 85376  [John Williams, London Symphony Orchestra]
# 85415  [John Williams, London Symphony Orchestra]
# 85522  [John Williams, London Symphony Orchestra]
# 85555  [John Williams, London Symphony Orchestra]
# 85525  [John Williams, London Symphony Orchestra]
# 85426  [John Williams, London Symphony Orchestra]
#
#                                             artists_song  \
# 85565                  John WilliamsBattle of the Heroes
# 85574                     John WilliamsAnakin's Betrayal
# 85573                   John WilliamsAnakin's Dark Deeds
# 85531                      John WilliamsGeneral Grievous
# 85445  John WilliamsStar Wars and the Revenge of the ...
# 85580            John WilliamsA New Hope and End Credits
# 85413                  John WilliamsThe Immolation Scene
# 85547                      John WilliamsEnter Lord Vader
# 85528       John WilliamsGrievous Speaks to Lord Sidious
# 85430  John WilliamsThe Birth of the Twins and Padmé'...
# 85446  John WilliamsStar Wars Main Title and the Arri...
# 85395  John WilliamsThe Sith Spacecraft and the Droid...
# 85431                John WilliamsThe Battle in the Snow
# 85447                John WilliamsStar Wars (Main Theme)
# 85433                    John WilliamsThe Asteroid Field
# 85539                                John WilliamsFinale
# 85463                         John WilliamsRebels at Bay
# 85423                              John WilliamsThe Duel
# 85568  John WilliamsAugie's Great Municipal Band and ...
# 85516                            John WilliamsHyperspace
# 85556                John WilliamsDeparture of Boba Fett
# 85497             John WilliamsLove Pledge and the Arena
# 85424  John WilliamsThe Droid Invasion and the Appear...
# 85435  John WilliamsThe Arrival at Tatooine and the F...
# 85416           John WilliamsThe Heroics of Luke and Han
# 85558  John WilliamsConfrontation with Count Dooku an...
# 85392         John WilliamsThe Training of a Jedi Knight
# 85407                        John WilliamsThe Magic Tree
# 85572                        John WilliamsAnakin's Theme
# 85500                        John WilliamsLando's Palace
# 85504  John WilliamsJar Jar's Introduction and the Sw...
# 85467                   John WilliamsQui-Gon's Noble End
# 85375                          John WilliamsYoda's Theme
# 85391  John WilliamsThe Trip to the Naboo Temple and ...
# 85376                    John WilliamsYoda and the Force
# 85415  John WilliamsThe High Council Meeting and Qui-...
# 85522                  John WilliamsHe Is the Chosen One
# 85555                          John WilliamsDesert Chase
# 85525             John WilliamsHan Solo and the Princess
# 85426                John WilliamsThe City in the Clouds
#
#                                 consolidates_genre_lists  popularity_red  \
# 85565  [orchestra, classical_performance, classical, ...              11
# 85574  [orchestra, classical_performance, classical, ...              11
# 85573  [orchestra, classical_performance, classical, ...              10
# 85531  [orchestra, classical_performance, classical, ...               8
# 85445  [orchestra, classical_performance, classical, ...               9
# 85580  [orchestra, classical_performance, classical, ...               8
# 85413  [orchestra, classical_performance, classical, ...               9
# 85547  [orchestra, classical_performance, classical, ...               9
# 85528  [orchestra, classical_performance, classical, ...               8
# 85430  [orchestra, classical_performance, classical, ...               8
# 85446  [orchestra, classical_performance, classical, ...              10
# 85395  [orchestra, classical_performance, classical, ...               8
# 85431  [orchestra, classical_performance, classical, ...               7
# 85447  [orchestra, classical_performance, classical, ...              10
# 85433  [orchestra, classical_performance, classical, ...               8
# 85539  [orchestra, classical_performance, classical, ...               8
# 85463  [orchestra, classical_performance, classical, ...               6
# 85423  [orchestra, classical_performance, classical, ...               7
# 85568  [orchestra, classical_performance, classical, ...               7
# 85516  [orchestra, classical_performance, classical, ...               7
# 85556  [orchestra, classical_performance, classical, ...               8
# 85497  [orchestra, classical_performance, classical, ...               9
# 85424  [orchestra, classical_performance, classical, ...               8
# 85435  [orchestra, classical_performance, classical, ...               7
# 85416  [orchestra, classical_performance, classical, ...               7
# 85558  [orchestra, classical_performance, classical, ...               7
# 85392  [orchestra, classical_performance, classical, ...               7
# 85407  [orchestra, classical_performance, classical, ...               6
# 85572  [orchestra, classical_performance, classical, ...               9
# 85500  [orchestra, classical_performance, classical, ...               7
# 85504  [orchestra, classical_performance, classical, ...               8
# 85467  [orchestra, classical_performance, classical, ...               8
# 85375  [orchestra, classical_performance, classical, ...               9
# 85391  [orchestra, classical_performance, classical, ...               7
# 85376  [orchestra, classical_performance, classical, ...               8
# 85415  [orchestra, classical_performance, classical, ...               7
# 85522  [orchestra, classical_performance, classical, ...               7
# 85555  [orchestra, classical_performance, classical, ...               7
# 85525  [orchestra, classical_performance, classical, ...               8
# 85426  [orchestra, classical_performance, classical, ...               7
#
